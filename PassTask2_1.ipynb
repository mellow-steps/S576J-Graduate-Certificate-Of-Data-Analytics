# %% [markdown]
# <a href="https://colab.research.google.com/github/mellow-steps/S576J-Graduate-Certificate-Of-Data-Analytics/blob/main/PassTask2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Out:
# --2024-04-25 02:41:59--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘iris.data’
#
# iris.data               [ <=>                ]   4.44K  --.-KB/s    in 0s
#
# 2024-04-25 02:42:00 (72.8 MB/s) - ‘iris.data’ saved [4551]

# %%
import pandas as pd

# Load the dataset into a Pandas DataFrame
iris_df = pd.read_csv('iris.data', header=None)

# Display the first few rows of the DataFrame
iris_df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
# Step 3: Create Column Headers
column_headers = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# Set the column headers to the DataFrame
iris_df.columns = column_headers

# Display the column headers
print("Column Headers:")
print(iris_df.columns)
# Out:
# Column Headers:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Step 4: Check for Missing Values
missing_values = iris_df.isnull().sum()

# Print the count of missing values
print("Count of Missing Values:")
print(missing_values)
# Out:
# Count of Missing Values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
import numpy as np

# %%
# Step 5: Set Values to NaN for Rows 10 to 29 of 'petal_length' column
iris_df.loc[10:29, 'petal_length'] = np.nan

# Display the updated DataFrame
print("Updated DataFrame:")
print(iris_df.head(30))  # Displaying the first 30 rows to verify changes
# Out:
# Updated DataFrame:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           NaN          0.2  Iris-setosa
# 11           4.8          3.4           NaN          0.2  Iris-setosa
# ...

# %%
# Step 6: Check for Missing Values Again
missing_values_after = iris_df['petal_length'].isnull().sum()

# Print the count of missing values after setting NaN values
print("Count of Missing Values After Setting NaN:")
print(missing_values_after)
# Out:
# Count of Missing Values After Setting NaN:
# 20

# %%
# Step 7: Substitute NaN Values with 10.0
iris_df['petal_length'].fillna(10.0, inplace=True)

# Display the updated DataFrame
print("Updated DataFrame:")
print(iris_df.head(30))  # Displaying the first 30 rows to verify changes
# Out:
# Updated DataFrame:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7          10.0          0.2  Iris-setosa
# 11           4.8          3.4          10.0          0.2  Iris-setosa
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(iris_df['sepal_length'], iris_df['sepal_width'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Length vs. Sepal Width')
plt.show()

# %% [markdown]
# # Section 2
#
# Python libraries such as Pandas, NumPy, and Matplotlib are fundamental for proficient data analysis. They empower users with versatile functionalities that streamline data manipulation, exploration, and visualization, thus enhancing the analytical process.
#
# Pandas furnishes powerful data structures like DataFrames, facilitating seamless handling of structured data. Common functionalities include NaN checks using the isna() function and dataset slicing with iloc[], which are essential for data cleaning and selective analysis.
#
# NumPy complements Pandas with efficient numerical computing capabilities, enabling mathematical operations on arrays and matrices. Its array manipulation functions are vital for tasks like reshaping and transforming data arrays.
#
# Matplotlib excels in data visualization, offering a wide range of plotting functions. For instance, the provided code snippet creates a scatter plot depicting the relationship between sepal length and sepal width from the Iris dataset. This visualization provides insights into the distribution and correlation between these two variables, aiding in data exploration and pattern identification.
#
# Overall, these libraries play a pivotal role in simplifying complex data analysis tasks and fostering data-driven decision-making processes.
